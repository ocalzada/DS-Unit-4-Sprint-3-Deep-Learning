# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# ## *Data Science Unit 4 Sprint 3 Lesson 1*
#
# # Recurrent Neural Networks and Long Short Term Memory (LSTM)
# ## _aka_ PREDICTING THE FUTURE!
#
# <img src="https://media.giphy.com/media/l2JJu8U8SoHhQEnoQ/giphy.gif" width=480 height=356>
# <br></br>
# <br></br>
#
# > "Yesterday's just a memory - tomorrow is never what it's supposed to be." -- Bob Dylan
#
# Wish you could save [Time In A Bottle](https://www.youtube.com/watch?v=AnWWj6xOleY)? With statistics you can do the next best thing - understand how data varies over time (or any sequential order), and use the order/time dimension predictively.
#
# A sequence is just any enumerated collection - order counts, and repetition is allowed. Python lists are a good elemental example - `[1, 2, 2, -1]` is a valid list, and is different from `[1, 2, -1, 2]`. The data structures we tend to use (e.g. NumPy arrays) are often built on this fundamental structure.
#
# A time series is data where you have not just the order but some actual continuous marker for where they lie "in time" - this could be a date, a timestamp, [Unix time](https://en.wikipedia.org/wiki/Unix_time), or something else. All time series are also sequences, and for some techniques you may just consider their order and not "how far apart" the entries are (if you have particularly consistent data collected at regular intervals it may not matter).

# %% [markdown]
# ## Recurrent Neural Networks
#
# There's plenty more to "traditional" time series, but the latest and greatest technique for sequence data is recurrent neural networks. A recurrence relation in math is an equation that uses recursion to define a sequence - a famous example is the Fibonacci numbers:
#
# $F_n = F_{n-1} + F_{n-2}$
#
# For formal math you also need a base case $F_0=1, F_1=1$, and then the rest builds from there. But for neural networks what we're really talking about are loops:
#
# ![Recurrent neural network](https://upload.wikimedia.org/wikipedia/commons/b/b5/Recurrent_neural_network_unfold.svg)
#
# The hidden layers have edges (output) going back to their own input - this loop means that for any time `t` the training is at least partly based on the output from time `t-1`. The entire network is being represented on the left, and you can unfold the network explicitly to see how it behaves at any given `t`.
#
# Different units can have this "loop", but a particularly successful one is the long short-term memory unit (LSTM):
#
# ![Long short-term memory unit](https://upload.wikimedia.org/wikipedia/commons/thumb/6/63/Long_Short-Term_Memory.svg/1024px-Long_Short-Term_Memory.svg.png)
#
# There's a lot going on here - in a nutshell, the calculus still works out and backpropagation can still be implemented. The advantage (ane namesake) of LSTM is that it can generally put more weight on recent (short-term) events while not completely losing older (long-term) information.
#
# After enough iterations, a typical neural network will start calculating prior gradients that are so small they effectively become zero - this is the [vanishing gradient problem](https://en.wikipedia.org/wiki/Vanishing_gradient_problem), and is what RNN with LSTM addresses. Pay special attention to the $c_t$ parameters and how they pass through the unit to get an intuition for how this problem is solved.
#
# So why are these cool? One particularly compelling application is actually not time series but language modeling - language is inherently ordered data (letters/words go one after another, and the order *matters*). [The Unreasonable Effectiveness of Recurrent Neural Networks](https://karpathy.github.io/2015/05/21/rnn-effectiveness/) is a famous and worth reading blog post on this topic.
#
# For our purposes, let's use TensorFlow and Keras to train RNNs with natural language. Resources:
#
# - https://github.com/keras-team/keras/blob/master/examples/imdb_lstm.py
# - https://keras.io/layers/recurrent/#lstm
# - http://adventuresinmachinelearning.com/keras-lstm-tutorial/
#
# Note that `tensorflow.contrib` [also has an implementation of RNN/LSTM](https://www.tensorflow.org/tutorials/sequences/recurrent).

# %% [markdown]
# ### RNN/LSTM Sentiment Classification with Keras

# %%
'''
#Trains an LSTM model on the IMDB sentiment classification task.
The dataset is actually too small for LSTM to be of any advantage
compared to simpler, much faster methods such as TF-IDF + LogReg.
**Notes**
- RNNs are tricky. Choice of batch size is important,
choice of loss and optimizer is critical, etc.
Some configurations won't converge.
- LSTM loss decrease patterns during training can be quite different
from what you see with CNNs/MLPs/etc.
'''
from __future__ import print_function

from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding
from tensorflow.keras.layers import LSTM
from tensorflow.keras.datasets import imdb

max_features = 20000
# cut texts after this number of words (among top max_features most common words)
maxlen = 80
batch_size = 32

print('Loading data...')
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
print(len(x_train), 'train sequences')
print(len(x_test), 'test sequences')
# Out:
# Loading data...
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# 25000 train sequences
# 25000 test sequences

# %%
len(x_train)
# Out:
# 25000

# %%
print('Pad sequences (samples x time)')
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# Pad sequences (samples x time)
# x_train shape: (25000, 80)
# x_test shape: (25000, 80)

# %%
x_train[0]
# Out:
# array([   15,   256,     4,     2,     7,  3766,     5,   723,    36,
#           71,    43,   530,   476,    26,   400,   317,    46,     7,
#            4, 12118,  1029,    13,   104,    88,     4,   381,    15,
#          297,    98,    32,  2071,    56,    26,   141,     6,   194,
#         7486,    18,     4,   226,    22,    21,   134,   476,    26,
#          480,     5,   144,    30,  5535,    18,    51,    36,    28,
#          224,    92,    25,   104,     4,   226,    65,    16,    38,
#         1334,    88,    12,    16,   283,     5,    16,  4472,   113,
#          103,    32,    15,    16,  5345,    19,   178,    32],
#       dtype=int32)

# %%
print('Build model...')
model = Sequential()
model.add(Embedding(max_features, 128))
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

# try using different optimizers and different optimizer configs
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print('Train...')
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=2,
          validation_data=(x_test, y_test))
score, acc = model.evaluate(x_test, y_test,
                            batch_size=batch_size)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# Build model...
# Train...
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/2
# 25000/25000 [==============================] - 101s 4ms/sample - loss: 0.4532 - accuracy: 0.7870 - val_loss: 0.3777 - val_accuracy: 0.8343
# Epoch 2/2
# 25000/25000 [==============================] - 99s 4ms/sample - loss: 0.3009 - accuracy: 0.8776 - val_loss: 0.3994 - val_accuracy: 0.8350
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test score: 0.399418170747757
# Test accuracy: 0.83496

# %% [markdown]
# ### LSTM Text generation with Keras
#
# What else can we do with LSTMs? Since we're analyzing the *sequence*, we can do more than classify - we can *generate* text. I'ved pulled some news stories using [newspaper](https://github.com/codelucas/newspaper/).
#
# This example is drawn from the Keras [documentation](https://keras.io/examples/lstm_text_generation/).

# %%
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.optimizers import RMSprop

import numpy as np
import random
import sys
import os

# %%
data_files = os.listdir('./articles')

# %%
# Read in Data
text = ""

for filename in data_files:
#     print(filename)
    if filename[-3:] == 'txt':
        path = f'./articles/{filename}'
        with open(path, 'r') as data:
            content = data.read()
#             print(content)
            text = text + " " + content
            
print('corpus length:', len(text))
# Out:
# corpus length: 891911

# %%
# Encode Data as Chars
chars = sorted(list(set(text)))
char_indices = dict((c,i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
text[:50]
# Out:
# ' We encourage new and innovative uses of our conte'

# %%
maxlen = 40
step = 3

sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('sequences:', len(sentences))
# Out:
# sequences: 297291

# %%
# Create the Sequence Data

sentences[0]
# Out:
# ' We encourage new and innovative uses of'

# %%
next_chars[1]
# Out:
# 'r'

# %%
# Specify x & y

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %%
print(x.shape)
print(y.shape)
# Out:
# (40, 40, 121)
# (40, 121)

# %%
# build the model: a single LSTM
x.shape
# Out:
# (297291, 40, 121)

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metric='acc')

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
model.fit(x, y,
          batch_size=128,
          epochs=5,
          callbacks=[print_callback])
# Out:
# Train on 297291 samples
# Epoch 1/5
# 296064/297291 [============================>.] - ETA: 0s - loss: 2.0791
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "could, then pieced it together from ther"
# could, then pieced it together from there destring the see and the services and president and the Services and contranting the site and and the sites and and the see which and the sees of the NFL and the destring and the sees the can and and the destained and and the commitions and the Services and the dencess the seen and the see and the stand and the lation of the Services and the dest and and the Services and the see and the restand
# ----- diversity: 0.5
# ----- Generating with seed: "could, then pieced it together from ther"
# could, then pieced it together from there which he can this the “Sher may all with her which his allical breading the deven the Washing a parting by Times the said and his soons are at the Mack and president and and you said the Sunday, and and which in the resting to only a Ror in the lake as a the monding to the tarks and online to destacting the services, and the discanting of the Trump of the Services, and conting the cained and a t
# ----- diversity: 1.0
# ----- Generating with seed: "could, then pieced it together from ther"
# could, then pieced it together from there stake usemIater, a Chincellet one and whac even properties, “white Fake sayy with mongskement serviested discame, impolective to 1k-Sy
#
# “This the priden but sigite Sing sites.
#
# To the Terms of me dedages. Racker or warlinish to vilicablesers mind trames withonts. Are a NAI , He legting, Trump’s use for frie” He Says. A mehirss of theses fries and what may while holluee’s clase and (white of the
# ----- diversity: 1.2
# ----- Generating with seed: "could, then pieced it together from ther"
# could, then pieced it together from there trignturmagiot barm Lim about Jodnen, relause brept. W4 and S-erbrack lan Unothora.Tistra, entil agle yeptive contribmitely. annentnal1’s beet paxer mecylys rekiss divailary,
#
# ol last 10, 2-0-J”. Ho shight.
#
# Hin7k serpen .ck. ’s an leantil iting 2luef“To. . as it was mongowi in . 24 the buar.
#
# -for like this yearvataral out prondical every in Infeonslers of abhond automicistring is in gPwherge b
# 297291/297291 [==============================] - 74s 249us/sample - loss: 2.0783
# Epoch 2/5
# 296192/297291 [============================>.] - ETA: 0s - loss: 1.7634
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "ld abuse, a reduced charge. He was sente"
# ld abuse, a reduced charge. He was sentence and the Services of the Washington’s and the Services and the Services in the provide and the Services and the United States and the look and starting to the Services as the United States and the United States and the United States and the Services to the United States, and The Washington’s a many that the President County and Stronile that the President Product the County in the Services and
# ----- diversity: 0.5
# ----- Generating with seed: "ld abuse, a reduced charge. He was sente"
# ld abuse, a reduced charge. He was sentence and the lort the least profect on his all than a loging in the supprime the decision that producing to say count, a to say from when the starting for the President succition even to lead for the Presidency in the United States and the the President Sentence a feed hare the Services. (Plicians The Washington’s and start that the provide of the content to make the property of the Terms of the Wa
# ----- diversity: 1.0
# ----- Generating with seed: "ld abuse, a reduced charge. He was sente"
# ld abuse, a reduced charge. He was senters other to militari— lore. the Lutory an over years are the Shiff finell election of Russianely, undergy 0genstion appear of your texchanner lation and reportide and necaneld hisnee helts in dined cate with Spingesra aster his seLort, even but blannel realt-for comerictuabild been wart but they winn and starttucts to find goacting . escliably that all breatue my  enserst, have subsiatifn’s if tha
# ----- diversity: 1.2
# ----- Generating with seed: "ld abuse, a reduced charge. He was sente"
# ld abuse, a reduced charge. He was sentemtite sentence and off all pedpork who changeptity colleve homeiany insidermpece a recouniual do us who troodsmone havili
# smely and his 206Kke take Mordue — in Chright)’ hear his arreknilss in reppesent du— go nortimeked by mantaund (Technorovic Atie
#
# I’ way spont as a theren. There, dow concepting Devil tatives be will NiPerment, it has do suckilesvooring firsd Yorhe, Youlk Newstrates Thirdhs-oo
# 297291/297291 [==============================] - 72s 243us/sample - loss: 1.7631
# Epoch 3/5
# 297088/297291 [============================>.] - ETA: 0s - loss: 1.6804
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "the jacket hung in Anita Henderson’s bas"
# the jacket hung in Anita Henderson’s base and the started to the procision of the United States and the Services. The political complesing the service of the greater the services and the prosons of the services of the be and the prosons and the prosided that the first services of the countries and and the procimed the became the restruction of the greater of the start of the services and the fight to the prosidence and the prosons to th
# ----- diversity: 0.5
# ----- Generating with seed: "the jacket hung in Anita Henderson’s bas"
# the jacket hung in Anita Henderson’s base is the said he and the president to any in the president Boshiew Chief Striater of the place and conterting the most of the access in the responding to ficusting service procision to the been the first provided the anexisse has the protesters of parist in the proliction of the many the proside of Striete Washington Bost the Services. For a one services and end on the amplease this sollere of the
# ----- diversity: 1.0
# ----- Generating with seed: "the jacket hung in Anita Henderson’s bas"
# the jacket hung in Anita Henderson’s basing up dedicters this for beingined to be a fyer is which begine, view simers seemating has sour. This fielces of which the reliveenton because with no soy “going 201d for ebsellies, no to thou. Han well negged and pollages.”
#
# AD
#
# years,” in less.”
#
# AD
#
# AD
#
# Pidational copleoping who becouse o torm Astay Unites Augh fights.”
#
# If her down ms. Thas overson alsowng. The Bung to We meetess of this law
# ----- diversity: 1.2
# ----- Generating with seed: "the jacket hung in Anita Henderson’s bas"
# the jacket hung in Anita Henderson’s basious wisnedity about nice said tometf-has requistened the ppeain, eogover, Trump’s wellsvers. Chinain sle of the racker the na yo , evennenias.”
#
# 5Deryobtasedorgreavy. ’s imbargess of otherwe reislating oftandonay, spicic deing to offers and seened this linsied of Collean reaton ake M I’m Amonia C. Stiret’s Adaida 1, Jocad Cargdannajors Braydurarges
#
# main GSgeterwha-Messaul Pecrees.
#
# strong, Malke
# 297291/297291 [==============================] - 73s 244us/sample - loss: 1.6805
# Epoch 4/5
# 296320/297291 [============================>.] - ETA: 0s - loss: 1.6360
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "meet with Epstein about fundraising. “Hi"
# meet with Epstein about fundraising. “His in the proppent of the company and the proppent to the proppent of the first in the proppent and the producers to the president in the company in the condection to the proppenders and the proppent to seve all the proppenal and the and the proppent to the proppent to be a capilary and and the and the state and the state of the promise of the condection to the producers to the proppent to the stat
# ----- diversity: 0.5
# ----- Generating with seed: "meet with Epstein about fundraising. “Hi"
# meet with Epstein about fundraising. “His schedule to an about the poster.
#
# AD
#
# AD
#
# AD
#
# AD
#
# AD
#
# AD
#
# AD
#
# AD
#
# The even one of the first Frestand of the White House or the state in a sunative and even without we sited the our recent to be a something the process with a calling the comprosed, as a statetic bording and stembush of the bases and the but and the start are was to desisters. The intervent to the did the promiser or approve with
# ----- diversity: 1.0
# ----- Generating with seed: "meet with Epstein about fundraising. “Hi"
# meet with Epstein about fundraising. “His anrodember from you truspetters. We transkit not state of sysationes pentation of year of statister decsials. It some bemon. Phieled how the approve you magees by the tevonlianfil recouration.
#
# The avera7d lcyess ceace me on the Collect. Tit approside actor of -take, when up not not her follower couchity crisare to mornafor, the deauld arrive pries and roed in a yiunt with Chinses backed one are
# ----- diversity: 1.2
# ----- Generating with seed: "meet with Epstein about fundraising. “Hi"
# meet with Epstein about fundraising. “His receutepen ew-idalthy) win old Hetifizor, died after ording noruc
#
# verack interaction Aidect would be ruporC’s Turkeys sid, Hillars,
#
# lePall .w. Shister dive.
#
# daskishia (for investigation Rosewnts, with A. S, Sxruc
# tint,” Mably. Rid restruct as left in sus). The IBeartically in. PraiseCmuls specials.
#
# AD
#
# fAinist of vouitbas, game prawned finrittroymal among Beup to stape lect qually because to
# 297291/297291 [==============================] - 75s 252us/sample - loss: 1.6362
# Epoch 5/5
# 297216/297291 [============================>.] - ETA: 0s - loss: 1.6077
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "cessarily as Trump has done with the Syr"
# cessarily as Trump has done with the Syria in the propogate of the company and the should be a continue and the some the state of the loud betally to the company the company and the state the company and the content for the concerns and the content and the prosod that the process should be the content of the consider to the contract that a product to the contract to the contract that the company and the process that the process to the c
# ----- diversity: 0.5
# ----- Generating with seed: "cessarily as Trump has done with the Syr"
# cessarily as Trump has done with the Syrian companies comes to the pair and with the internetain ranger that the adding at trade and make the congression as the submit of the prosodate in the confiame that we was a uncaved him to the something the process to the sentence to the rong sent of the lined that reader of said that discustices are reported the proposal about the more according to have for the state that according the advertisi
# ----- diversity: 1.0
# ----- Generating with seed: "cessarily as Trump has done with the Syr"
# cessarily as Trump has done with the Syrian, the patner, aft of the dinditience.”
#
# unries of the aps.als womalogim
#
#
#
# undey saater of over third said  to choices. 2. 3, extimation, last Pattrapsh, alard come with the gets justices, eacth childrengerple workers connent and diSweet dentons. And would rich, Conrehl. (viclimation.
#
# “No who wrighes or any coallaking of a Rediban Hin rig problems for 1id Isticts Les)
#
#
#
# thats carding for it.
# ----- diversity: 1.2
# ----- Generating with seed: "cessarily as Trump has done with the Syr"
# cessarily as Trump has done with the Syrie, moreded that reprement vighous ir.AHEaNTfares was scheation. (DeN-NACwS AHOAlgin 10Gerh like fext I  Party Accramato.cuanh. You daildran’s at what os the way to “Wreed — drew allort w for A Aid laok , Aviboking who attacks,” acumes chaald that the Riarenn about hitgernaters that us sequite. at hoaders that Trump, Roa Philick Rones Medily Cover. At fanizenss that did more.” Heon, overqI3s.”
#
# On
# 297291/297291 [==============================] - 73s 246us/sample - loss: 1.6078
